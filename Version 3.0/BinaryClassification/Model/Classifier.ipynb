# %%
train_labels = {
    "1.pdf":[5,6,8],
    "2.pdf":[4,5,7],
    "3.pdf":[5,6,8],
    "4.pdf":[4,5,8],
    "5.pdf":[4,5,7],
    "6.pdf":[4,5,7,8],
    "7.pdf":[4,5,7],
    "8.pdf":[5,6,8],
    "9.pdf":[4,5,7],
    "10.pdf":[5,6,8]
}

test_labels = {
    "1.pdf":[4,5,7],
    "2.pdf":[4,5,7],
    "3.pdf":[4,5,7],
    "4.pdf":[5,6,8],
    "5.pdf":[2,3,5],
    "6.pdf":[4,5,7],
    "7.pdf":[4,5,7],
    "8.pdf":[4,5,7],
    "9.pdf":[4,5,7],
    "10.pdf":[4,5,7] 
}

# %%
import glob
import PyPDF2, os
import pickle
import pandas 
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
import string,re
def cleanText(text):
    corpus =text.lower().strip().split()
    stop_words = set(stopwords.words('english'))
    clean_corpus = []
    regex = re.compile('[^a-zA-Z0-9]')
    for i in corpus:
        if len(i) > 5:
            if i not in stop_words:
                i = regex.sub('',i)
                clean_corpus.append(i)
    clean_corpus = word_tokenize(" ".join(clean_corpus))
    result = []
    seen = set()
    for item in clean_corpus:
        if item not in seen:
            seen.add(item)
            result.append(item)
    return result
    
        
    
    

trainFiles = os.getcwd()
print(trainFiles)
train_PDF = glob.glob("*.pdf")
print(train_PDF)
trainedSet = []
for pdf in train_PDF:
    print(pdf)
    book = []
    pdfFileObj = open(pdf,'rb')     
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    num_pg = pdfReader.numPages
    
    for page in range(num_pg):
        #adj_pg_num = page + 1
        #policy_pages = train_labels[pdf]
        #category = 0
        #if adj_pg_num in policy_pages:
            #category = 1
        if page > 12:
            break
        pageObj = pdfReader.getPage(page)          
        text = pageObj.extractText()
        found = text.find("Insurance Companies Act")
        print(found)
       
        #clean_text = cleanText(text)
        #book.append([category,clean_text])
    
    #trainedSet.append(book)
#with open('labeled_training_set.pickle','wb') as handle:
    #a = pickle.dump(trainedSet,handle)
# Out:
# C:\Users\e95645\Documents\PDFExtractionTool\Binary Classification\PDF_Data
# ...

# %%
with open('labeled_training_set.pickle','rb') as handle:
    b = pickle.load(handle)
results = []
for i in b:
    resultVector = dict()
    for x in i:
        for u in x[1]:
            resultVector.update({u:True})
        results.append([(resultVector,x[0])])
classifier = nltk.NaiveBayesClassifier.train(ans)
prob_dis = classifier.prob_classify(ans)
print(classifier.prob_dis.prob(1))

# %%
def textFeature((text,category)):
    for item in (text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-f98f3c365ffd> in <module>
#       1 import nltk
# ----> 2 classifier = nltk.NaiveBayesClassifier.train(b)
#
# c:\users\e95645\appdata\local\programs\python\python37-32\lib\site-packages\nltk\classify\naivebayes.py in train(cls, labeled_featuresets, estimator)
#     204         # Count up how many times each feature value occurred, given
#     205         # the label and featurename.
# --> 206         for featureset, label in labeled_featuresets:
#     207             label_freqdist[label] += 1
#     208             for fname, fval in featureset.items():
#
# ValueError: too many values to unpack (expected 2)
